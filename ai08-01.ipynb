# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("house_price.csv")
df
# Out:
#      Square Footage/Area  Number of Bedrooms  Number of Bathrooms  Year Built  \
# 0                   1360                   2                    1        1931
# 1                   4272                   3                    3        1966
# 2                   3592                   1                    2        1966
# 3                    966                   1                    2        1927
# 4                   4926                   2                    1        1943
# ..                   ...                 ...                  ...         ...
# 995                 3261                   4                    1        1952
# 996                 3179                   1                    2        2019
# 997                 2606                   4                    2        2015
# 998                 4723                   5                    2        1922
# 999                 3268                   4                    2        2008
#
#      Number of Floors  Distance to City Center  Age of House    House Price
# 0                   1                21.598000            94   18589.261072
# 1                   3                 8.816612            59  216574.894902
# 2                   2                11.232384            59  156828.849255
# 3                   1                 6.126417            98   22953.978863
# 4                   2                10.738340            82  208444.870562
# ..                ...                      ...           ...            ...
# 995                 3                26.634463            73  175486.089126
# 996                 3                24.574332             6  118042.115490
# 997                 3                 1.058889            10  260338.235848
# 998                 2                22.209580           103  209617.887250
# 999                 1                 6.647787            17  118241.299863
#
# [1000 rows x 8 columns]

# %%
sns.joingrid(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Square Footage/Area      1000 non-null   int64
#  1   Number of Bedrooms       1000 non-null   int64
#  2   Number of Bathrooms      1000 non-null   int64
#  3   Year Built               1000 non-null   int64
#  4   Number of Floors         1000 non-null   int64
#  5   Distance to City Center  1000 non-null   float64
#  6   Age of House             1000 non-null   int64
#  7   House Price              1000 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 62.6 KB

# %%
x = df.iloc[:,:7]
x
# Out:
#      Square Footage/Area  Number of Bedrooms  Number of Bathrooms  Year Built  \
# 0                   1360                   2                    1        1931
# 1                   4272                   3                    3        1966
# 2                   3592                   1                    2        1966
# 3                    966                   1                    2        1927
# 4                   4926                   2                    1        1943
# ..                   ...                 ...                  ...         ...
# 995                 3261                   4                    1        1952
# 996                 3179                   1                    2        2019
# 997                 2606                   4                    2        2015
# 998                 4723                   5                    2        1922
# 999                 3268                   4                    2        2008
#
#      Number of Floors  Distance to City Center  Age of House
# 0                   1                21.598000            94
# 1                   3                 8.816612            59
# 2                   2                11.232384            59
# 3                   1                 6.126417            98
# 4                   2                10.738340            82
# ..                ...                      ...           ...
# 995                 3                26.634463            73
# 996                 3                24.574332             6
# 997                 3                 1.058889            10
# 998                 2                22.209580           103
# 999                 1                 6.647787            17
#
# [1000 rows x 7 columns]

# %%
y = df.iloc[:,-1]
y
# Out:
# 0       18589.261072
# 1      216574.894902
# 2      156828.849255
# 3       22953.978863
# 4      208444.870562
#            ...
# 995    175486.089126
# 996    118042.115490
# 997    260338.235848
# 998    209617.887250
# 999    118241.299863
# Name: House Price, Length: 1000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state = 30)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predict = lr.predict(x_test)

# %%
df.head(3)
# Out:
#    Square Footage/Area  Number of Bedrooms  Number of Bathrooms  Year Built  \
# 0                 1360                   2                    1        1931
# 1                 4272                   3                    3        1966
# 2                 3592                   1                    2        1966
#
#    Number of Floors  Distance to City Center  Age of House    House Price
# 0                 1                21.598000            94   18589.261072
# 1                 3                 8.816612            59  216574.894902
# 2                 2                11.232384            59  156828.849255

# %%
# y = b1x1 + b2x2 + b3x3 + b4x4 + b5x5 + b6x6 + b7+x7 + bo
bo = lr.intercept_
# print(bo)
bm = lr.coef_
print(bm)
b1 = bm[0]
b2 = bm[1]
b3 = bm[2]
b4 = bm[3]
b5 = bm[4]
b6 = bm[5]
b7 = bm[6]
# print(b1)
# print(b2)
# print(b3)
# print(b4)
# print(b5)
# print(b6)
# print(b7)
y = (b1*4272) + (b2*3) + (b3*3) + (b4*1966) + (b5*3) + (b6*8.816612) + (b7*59) + bo
y
# Out:
# [   49.38758934 12705.65189078 14179.72455822   231.66052431
#  16134.03076138 -2666.82422094  -231.66052431]
# np.float64(265557.680953039)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, predict)
# Out:
# 0.7053684426077866

# %%
import joblib
joblib.dump(lr,"house_price_predictor.joblib")
# Out:
# ['house_price_predictor.joblib']
