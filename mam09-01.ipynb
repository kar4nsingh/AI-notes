# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
dd = pd.read_csv("icecream_data.csv")
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Temperature (°C)         49 non-null     float64
#  1   Ice Cream Sales (units)  49 non-null     float64
# dtypes: float64(2)
# memory usage: 916.0 bytes

# %%
plt.scatter(dd["Temperature (°C)"],dd["Ice Cream Sales (units)"])

# %%
x = dd.iloc[:,0:1]
y = dd.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state = 34)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 40 to 33
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Temperature (°C)  39 non-null     float64
# dtypes: float64(1)
# memory usage: 624.0 bytes

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred  = lr.predict(x_test)

# %%
r2_score(x_test,y_pred)
# Out:
# -63.289568141636494

# %%
plt.scatter(dd["Temperature (°C)"],dd["Ice Cream Sales (units)"])
plt.plot(x_test,y_pred)

# %%
from sklearn.preprocessing import PolynomialFeatures
p = PolynomialFeatures(degree = 2)
x_poly = p.fit_transform(x)

# %%
x.loc[0]
# Out:
# Temperature (°C)   -4.662263
# Name: 0, dtype: float64

# %%
x_poly[0]
# Out:
# array([ 1.        , -4.66226268, 21.73669327])

# %%
lr = LinearRegression()

# %%
lr.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_poly)

# %%
r2_score(y,y_pred)
# Out:
# 0.9321137090423876

# %%
plt.scatter(dd["Temperature (°C)"],dd["Ice Cream Sales (units)"])
plt.plot(x,y_pred)

# %%
from sklearn.preprocessing import PolynomialFeatures
p = PolynomialFeatures(degree = 20)
x_poly = p.fit_transform(x)
lr = LinearRegression()
lr.fit(x_poly,y)
y_pred = lr.predict(x_poly)
print(r2_score(y,y_pred))
plt.scatter(dd["Temperature (°C)"],dd["Ice Cream Sales (units)"])
plt.plot(x,y_pred)
# Out:
# 0.966082886487303
