# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("student_performance_data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Hours Studied        250 non-null    float64
#  1   Attendance Rate (%)  250 non-null    float64
#  2   Final Exam Score     250 non-null    float64
# dtypes: float64(3)
# memory usage: 6.0 KB

# %%
x = df.iloc[:,0:2]
y  = df.iloc[:,-1]

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state = 2)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 74 to 168
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Hours Studied        200 non-null    float64
#  1   Attendance Rate (%)  200 non-null    float64
# dtypes: float64(2)
# memory usage: 4.7 KB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 89 to 77
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Hours Studied        50 non-null     float64
#  1   Attendance Rate (%)  50 non-null     float64
# dtypes: float64(2)
# memory usage: 1.2 KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 200 entries, 74 to 168
# Series name: Final Exam Score
# Non-Null Count  Dtype
# --------------  -----
# 200 non-null    float64
# dtypes: float64(1)
# memory usage: 3.1 KB

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 50 entries, 89 to 77
# Series name: Final Exam Score
# Non-Null Count  Dtype
# --------------  -----
# 50 non-null     float64
# dtypes: float64(1)
# memory usage: 800.0 bytes

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
df.head(2)
# Out:
#    Hours Studied  Attendance Rate (%)  Final Exam Score
# 0      10.747912            99.386119         84.550973
# 1      18.397112            71.388657         88.017165

# %%
# y = b1x1 + b2x2 + bo

bo = lr.intercept_
print(bo)
bm = lr.coef_
b1 = bm[0]
b2 = bm[1]
bm


# y = (b1 * 18.397112)+ (b2 *71.388657) + bo
# y


# y = (b1 * 19.392342)+ (b2 *78.365657) + bo
# y
# Out:
# 3.154610822047289
# array([2.95619022, 0.4669685 ])

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9152403671987963

# %%
import joblib
joblib.dump(lr, "performance_predictor.joblib")
# Out:
# ['performance_predictor.joblib']
